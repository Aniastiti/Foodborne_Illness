# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
occur_df = pd.read_csv('../data_files/dist_org_prep_2009_2015_CDC.csv')
occur_df
# Out:
#        Year  Month      State  \
# 0      2009      1  Minnesota
# 1      2009      1  Minnesota
# 2      2009      1  Minnesota
# 3      2009      1  Minnesota
# 4      2009      1  Minnesota
# ...     ...    ...        ...
# 19114  2014     12      Idaho
# 19115  2015      3      Idaho
# 19116  2015      9      Idaho
# 19117  2015     11      Idaho
# 19118  2015     12       Utah
#
#                                            Genus Species Serotype or Genotype  \
# 0                                              Norovirus                  NaN
# 1                                              Norovirus                  NaN
# 2                                              Norovirus                  NaN
# 3                                              Norovirus                  NaN
# 4                                              Norovirus                  NaN
# ...                                                  ...                  ...
# ...

# %%
adv_effects_df = pd.read_csv('../data_files/adverse_effects_2004_2016_FDA.csv')
adv_effects_df
# Out:
# C:\Users\pokey\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        RA_Report # RA_CAERS Created Date AEC_Event Start Date  \
# 0            65325              1/1/2004             8/4/2003
# 1            65333              1/1/2004                  NaN
# 2            65335              1/1/2004           11/24/2003
# 3            65336              1/1/2004                  NaN
# 4            65345              1/1/2004           12/21/2003
# ...            ...                   ...                  ...
# 80164       205724            12/28/2016           12/17/2016
# 80165       205753            12/28/2016                  NaN
# 80166       205814            12/29/2016           12/25/2016
# 80167       205817            12/29/2016           12/27/2010
# ...
