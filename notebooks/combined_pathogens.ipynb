# %%
import pandas as pd

# %% [markdown]
# # Campylobacter all species

# %%
allpathogens = pd.read_excel('../data_files/Total_cost_for_top_15_pathogens_2018_USDA.xlsx', usecols='A:C', skiprows=4)
allpathogens = allpathogens.dropna().rename(columns = {'Unnamed: 0': 'causative_agent'}).drop(index=16)
allpathogens
# Out:
#                                       causative_agent      Cases          Cost
# 0                    Campylobacter spp. (all species)   845024.0  2.181486e+09
# 1                             Clostridium perfringens   965958.0  3.842779e+08
# 2                  Cryptosporidium spp. (all species)    57616.0  5.839415e+07
# 3                             Cyclospora cayetanensis    11407.0  2.571518e+06
# 4                              Listeria monocytogenes     1591.0  3.189686e+09
# 5                                           Norovirus  5461731.0  2.566984e+09
# 6                  Salmonella (non-typhoidal species)  1027561.0  4.142179e+09
# 7                              Shigella (all species)   131254.0  1.592024e+08
# 8   Shiga toxin-producing Escherichia coli O157 (S...    63153.0  3.110369e+08
# 9   non-O157 Shiga toxin-producing Escherichia col...   112752.0  3.170185e+07
# 10                                  Toxoplasma gondii    86686.0  3.744009e+09
# ...
