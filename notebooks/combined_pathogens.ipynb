# %%
import pandas as pd

# %%
#Cristina's code for removing nested columns:

# col_df = pd.read_csv('../data/2016-table2h.txt', sep=r'\\t', engine='python', skiprows = 3, nrows = 9)
# columns = [col for col in col_df['Reporting Area']]
# print(columns)

# %% [markdown]
# # Campylobacter all species

# %%
campy = pd.read_excel('../data_files/Campylobacter_2018.xlsx', sheet_name='Campylobacter mean CoI 2018', 
                      usecols='A:L', skiprows=5)
campy = campy.dropna(thresh=2)
campy['Health outcomes'] = campy['Health outcomes'].fillna(campy['Unnamed: 1']).to_frame()
campy = campy.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
campy['causative_agent'] = 'Campylobacter'
campy = campy.reset_index(drop=True)
campy
# Out:
#                       Health outcomes   Total cases  \
# 0                     Number of cases  8.450240e+05
# 1                    Cases by outcome           NaN
# 2             Physician office visits           NaN
# 3               Emergency room visits           NaN
# 4            Outpatient clinic visits           NaN
# 5                    Hospitalizations           NaN
# 6      Total medical costs by outcome           NaN
# 7                     Premature death           NaN
# 8   Productivity loss, nonfatal cases           NaN
# 9              Total costs by outcome           NaN
# 10              Total cost of illness  2.181486e+09
#
#     Didn't visit physician; recovered  Visited physician; recovered  \
# 0                                 NaN                           NaN
# 1                        7.909297e+05                  4.563130e+04
# 2                                 NaN                  9.330174e+06
# 3                                 NaN                  3.196530e+06
# 4                                 NaN                  1.102724e+07
# 5                                 NaN                  0.000000e+00
# 6                                 NaN                  2.355394e+07
# 7                                 NaN                           NaN
# 8                        4.819250e+07                  8.670438e+06
# 9                        4.819250e+07                  3.222438e+07
# 10                                NaN                           NaN
#
#     Hospitalized  Post-hospitalization recovery  Hospitalized; died  \
# 0            NaN                            NaN                 NaN
# 1   8.463000e+03                   8.387000e+03        7.600000e+01
# 2   8.652095e+05                   1.224914e+06                 NaN
# 3   1.778531e+06                   0.000000e+00                 NaN
# 4   1.363443e+06                   0.000000e+00                 NaN
# 5   1.473915e+08                   0.000000e+00                 NaN
# 6   1.513987e+08                   1.224914e+06                 NaN
# 7            NaN                            NaN        7.373989e+08
# 8   4.640875e+06                   2.299599e+06                 NaN
# 9   1.560396e+08                   3.524513e+06        7.373989e+08
# 10           NaN                            NaN                 NaN
#
#     Morbidity illness with Guillan Barré syndrome  \
# 0                                             NaN
# 1                                    1.916000e+03
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                    3.653148e+08
# 10                                            NaN
#
#     Death associated with Guillan  Barré syndrome causative_agent
# 0                                             NaN   Campylobacter
# 1                                    8.645000e+01   Campylobacter
# 2                                             NaN   Campylobacter
# 3                                             NaN   Campylobacter
# 4                                             NaN   Campylobacter
# 5                                             NaN   Campylobacter
# 6                                             NaN   Campylobacter
# 7                                    8.387912e+08   Campylobacter
# 8                                             NaN   Campylobacter
# 9                                    8.387912e+08   Campylobacter
# 10                                            NaN   Campylobacter

# %%
campy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 10 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Health outcomes                                11 non-null     object
#  1   Total cases                                    2 non-null      float64
#  2   Didn't visit physician; recovered              3 non-null      float64
#  3   Visited physician; recovered                   8 non-null      float64
#  4   Hospitalized                                   8 non-null      float64
#  5   Post-hospitalization recovery                  8 non-null      float64
#  6   Hospitalized; died                             3 non-null      float64
#  7   Morbidity illness with Guillan Barré syndrome  2 non-null      float64
#  8   Death associated with Guillan  Barré syndrome  3 non-null      float64
#  9   causative_agent                                11 non-null     object
# dtypes: float64(8), object(2)
# memory usage: 1008.0+ bytes

# %% [markdown]
# # Clostridium perfringens

# %%
cper = pd.read_excel('../data_files/Clostridium_2018.xlsx', sheet_name='C. perfringens mean COI 2018', 
                     usecols='A:J', skiprows=5)
cper = cper.dropna(thresh=2)
cper['Health outcomes'] = cper['Health outcomes'].fillna(cper['Unnamed: 1']).to_frame()
cper = cper.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
cper['causative_agent'] = 'C. perfringens'
cper = cper.reset_index(drop=True)
cper
# Out:
#                       Health outcomes   Total cases  \
# 0                     Number of cases  9.659580e+05
# 1                    Cases by outcome           NaN
# 2             Physician office visits           NaN
# 3               Emergency room visits           NaN
# 4            Outpatient clinic visits           NaN
# 5                    Hospitalizations           NaN
# 6      Total medical costs by outcome           NaN
# 7                     Premature death           NaN
# 8   Productivity loss, nonfatal cases           NaN
# 9               Total cost by outcome           NaN
# 10              Total cost of Illness  3.842779e+08
#
#     Didn't visit physician; recovered  Visited physician; recovered  \
# 0                                 NaN                           NaN
# 1                        8.698902e+05                  9.562984e+04
# 2                                 NaN                  1.955331e+07
# 3                                 NaN                  6.698991e+06
# 4                                 NaN                  2.310986e+07
# 5                                 NaN                           NaN
# 6                                 NaN                  4.936217e+07
# 7                                 NaN                           NaN
# 8                        5.300367e+07                  1.615173e+07
# 9                        5.300367e+07                  6.551390e+07
# 10                                NaN                           NaN
#
#     Hospitalized  Post-hospitalization recovery  Hospitalized; died  \
# 0            NaN                            NaN                 NaN
# 1   4.380000e+02                     412.000000        2.600000e+01
# 2   4.477866e+04                   60172.231655                 NaN
# 3   9.204736e+04                       0.000000                 NaN
# 4   7.056458e+04                       0.000000                 NaN
# 5   1.303859e+07                            NaN                 NaN
# 6   1.324598e+07                   60172.231655                 NaN
# 7            NaN                            NaN        2.522680e+08
# 8   1.143748e+05                   71723.619213                 NaN
# 9   1.336036e+07                  131895.850868        2.522680e+08
# 10           NaN                            NaN                 NaN
#
#    causative_agent
# 0   C. perfringens
# 1   C. perfringens
# 2   C. perfringens
# 3   C. perfringens
# 4   C. perfringens
# 5   C. perfringens
# 6   C. perfringens
# 7   C. perfringens
# 8   C. perfringens
# 9   C. perfringens
# 10  C. perfringens
